# %% [markdown]
# # Explore iNaturalist plant data

# %% [markdown]
# There is nothing really important here except that I used the techniques and information discovered here later in other notebooks.

# %%
from pathlib import Path
from types import SimpleNamespace

import polars as pl

# %%
DATA_DIR = Path("..") / "data"
INAT = DATA_DIR / "inat" / "inaturalist-open-data-20221227"

# %%
args = SimpleNamespace(
    observations=INAT / "observations.csv",
    photos=INAT / "photos.csv",
    taxa=INAT / "taxa.csv",
)

# %% [markdown]
# ## Get total number of records in CSVs

# %%
# !wc -l $INAT/*
# Out:
#    89600604 ../data/inat/inaturalist-open-data-20221227/observations.csv
#      589291 ../data/inat/inaturalist-open-data-20221227/observers.csv
#   153429245 ../data/inat/inaturalist-open-data-20221227/photos.csv
#     1394174 ../data/inat/inaturalist-open-data-20221227/taxa.csv
#   245013314 total

# %%
taxa_df = pl.read_csv(
    args.taxa,
    sep="\t",
    dtypes=[pl.Int64, pl.Utf8, pl.Float32, pl.Utf8, pl.Utf8, pl.Boolean],
).lazy()

# %%
taxa_df.filter(pl.col("rank") == "kingdom").filter(pl.col("active")).collect()
# Out:
# shape: (8, 6)
# ┌──────────┬──────────┬────────────┬─────────┬───────────┬────────┐
# │ taxon_id ┆ ancestry ┆ rank_level ┆ rank    ┆ name      ┆ active │
# │ ---      ┆ ---      ┆ ---        ┆ ---     ┆ ---       ┆ ---    │
# │ i64      ┆ str      ┆ f32        ┆ str     ┆ str       ┆ bool   │
# ╞══════════╪══════════╪════════════╪═════════╪═══════════╪════════╡
# │ 1        ┆ 48460    ┆ 70.0       ┆ kingdom ┆ Animalia  ┆ true   │
# │ 47170    ┆ 48460    ┆ 70.0       ┆ kingdom ┆ Fungi     ┆ true   │
# │ 47126    ┆ 48460    ┆ 70.0       ┆ kingdom ┆ Plantae   ┆ true   │
# │ 48222    ┆ 48460    ┆ 70.0       ┆ kingdom ┆ Chromista ┆ true   │
# │ 47686    ┆ 48460    ┆ 70.0       ┆ kingdom ┆ Protozoa  ┆ true   │
# │ 67333    ┆ 48460    ┆ 70.0       ┆ kingdom ┆ Bacteria  ┆ true   │
# │ 131236   ┆ 48460    ┆ 70.0       ┆ kingdom ┆ Viruses   ┆ true   │
# │ 151817   ┆ 48460    ┆ 70.0       ┆ kingdom ┆ Archaea   ┆ true   │
# └──────────┴──────────┴────────────┴─────────┴───────────┴────────┘

# %% [markdown]
# ## Get plant species IDs

# %%
species = (
    taxa_df.filter(pl.col("ancestry").str.contains("/47126/", literal=True))
    .filter(pl.col("rank") == "species")
    .collect()
    # .filter(pl.col('active'))
)
species = species.to_series(0)
species.head()
# Out:
# shape: (10,)
# Series: 'taxon_id' [i64]
# [
# 	47849
# 	48280
# 	48696
# 	48279
# 	49559
# 	48278
# 	47893
# 	49386
# 	49002
# 	49526
# ]

# %%
species.shape
# Out:
# (283844,)

# %% [markdown]
# ## Get plant order IDs

# %%
orders = (
    taxa_df.filter(pl.col("ancestry").str.contains("/47126/", literal=True))
    .filter(pl.col("rank") == "order")
    .collect()
    # .filter(pl.col('active'))
)
orders = orders.to_series(0)
orders.head()
# Out:
# shape: (10,)
# Series: 'taxon_id' [i64]
# [
# 	48808
# 	47363
# 	47218
# 	47195
# 	48232
# 	47123
# 	47754
# 	47162
# 	48700
# 	47729
# ]

# %%
orders.shape
# Out:
# (269,)

# %% [markdown]
# ## Link species to orders

# %%
taxa = {}
for order in orders:
    ancestry = f"/{order}/"
    df = (
        taxa_df.filter(pl.col("ancestry").str.contains(ancestry, literal=True))
        .filter(pl.col("rank") == "species")
        .collect()
    )
    taxa[order] = df.to_series(0)

# %%
# for order, species in taxa.items():
#     print(f"{order}: {len(species)}")

sum(len(v) for k, v in taxa.items())
# Out:
# 283665

# %% [markdown]
# ## Get plant observation records

# %%
obs_df = pl.read_csv(args.observations, sep="\t").lazy()

# %%
obs_df = (
    obs_df.filter(pl.col("taxon_id").is_in(species))
    .filter(pl.col("quality_grade") == "research")
    .collect()
)
obs_df.head()
# Out:
# shape: (5, 8)
# ┌────────────┬───────────┬────────────┬───────────┬────────────┬──────────┬────────────┬───────────┐
# │ observatio ┆ observer_ ┆ latitude   ┆ longitude ┆ positional ┆ taxon_id ┆ quality_gr ┆ observed_ │
# │ n_uuid     ┆ id        ┆ ---        ┆ ---       ┆ _accuracy  ┆ ---      ┆ ade        ┆ on        │
# │ ---        ┆ ---       ┆ f64        ┆ f64       ┆ ---        ┆ i64      ┆ ---        ┆ ---       │
# │ str        ┆ i64       ┆            ┆           ┆ i64        ┆          ┆ str        ┆ str       │
# ╞════════════╪═══════════╪════════════╪═══════════╪════════════╪══════════╪════════════╪═══════════╡
# │ 2fee38b7-f ┆ 477       ┆ -16.214675 ┆ -56.20605 ┆ null       ┆ 169520   ┆ research   ┆ 2009-08-1 │
# │ 1e1-4f59-a ┆           ┆            ┆ 5         ┆            ┆          ┆            ┆ 0         │
# │ 892-9534f2 ┆           ┆            ┆           ┆            ┆          ┆            ┆           │
# │ 7a...      ┆           ┆            ┆           ┆            ┆          ┆            ┆           │
# │ bc2bf26b-b ┆ 477       ┆ -23.117116 ┆ -46.55021 ┆ null       ┆ 120490   ┆ research   ┆ 2009-08-1 │
# │ 6cc-4d8b-9 ┆           ┆            ┆ 6         ┆            ┆          ┆            ┆ 0         │
# │ 3e8-9d2239 ┆           ┆            ┆           ┆            ┆          ┆            ┆           │
# │ 10...      ┆           ┆            ┆           ┆            ┆          ┆            ┆           │
# │ d2067277-8 ┆ 477       ┆ -16.262141 ┆ -56.17309 ┆ null       ┆ 67511    ┆ research   ┆ 2009-08-1 │
# │ c40-4266-a ┆           ┆            ┆ 6         ┆            ┆          ┆            ┆ 0         │
# │ 356-a2e907 ┆           ┆            ┆           ┆            ┆          ┆            ┆           │
# │ e3...      ┆           ┆            ┆           ┆            ┆          ┆            ┆           │
# │ 63c6eebc-5 ┆ 477       ┆ -16.24632  ┆ -56.20605 ┆ null       ┆ 962649   ┆ research   ┆ 2009-08-1 │
# │ 228-4ed9-8 ┆           ┆            ┆ 5         ┆            ┆          ┆            ┆ 0         │
# │ 929-1d23ef ┆           ┆            ┆           ┆            ┆          ┆            ┆           │
# │ 24...      ┆           ┆            ┆           ┆            ┆          ┆            ┆           │
# │ 1eb58e5c-3 ┆ 477       ┆ 46.789153  ┆ -121.7355 ┆ null       ┆ 67525    ┆ research   ┆ 2010-08-1 │
# │ f93-4d0a-a ┆           ┆            ┆ 54        ┆            ┆          ┆            ┆ 3         │
# │ 258-14e257 ┆           ┆            ┆           ┆            ┆          ┆            ┆           │
# │ 9d...      ┆           ┆            ┆           ┆            ┆          ┆            ┆           │
# └────────────┴───────────┴────────────┴───────────┴────────────┴──────────┴────────────┴───────────┘

# %%
obs_df.shape
# Out:
# (20459827, 8)

# %% [markdown]
# ## Get plant observation IDs

# %%
obs_ids = obs_df.to_series(0)
obs_ids.head()
# Out:
# shape: (10,)
# Series: 'observation_uuid' [str]
# [
# 	"2fee38b7-f1e1-...
# 	"bc2bf26b-b6cc-...
# 	"d2067277-8c40-...
# 	"63c6eebc-5228-...
# 	"1eb58e5c-3f93-...
# 	"a46aca09-df98-...
# 	"f1fa6354-c0e7-...
# 	"d7b37f38-87ae-...
# 	"ef55e0f4-7a8c-...
# 	"725595c8-4a2a-...
# ]

# %% [markdown]
# ## Get plant photo records

# %%
photo_df = pl.read_csv(args.photos, sep="\t").lazy()

# %%
photo_df = (
    photo_df.filter(pl.col("observation_uuid").is_in(obs_ids))
    .filter(pl.col("license").str.contains("CC", literal=True))
    .collect()
)
photo_df.head()
# Out:
# shape: (5, 9)
# ┌──────────────┬──────────┬──────────────┬─────────────┬─────┬─────────┬───────┬────────┬──────────┐
# │ photo_uuid   ┆ photo_id ┆ observation_ ┆ observer_id ┆ ... ┆ license ┆ width ┆ height ┆ position │
# │ ---          ┆ ---      ┆ uuid         ┆ ---         ┆     ┆ ---     ┆ ---   ┆ ---    ┆ ---      │
# │ str          ┆ i64      ┆ ---          ┆ i64         ┆     ┆ str     ┆ i64   ┆ i64    ┆ i64      │
# │              ┆          ┆ str          ┆             ┆     ┆         ┆       ┆        ┆          │
# ╞══════════════╪══════════╪══════════════╪═════════════╪═════╪═════════╪═══════╪════════╪══════════╡
# │ 0a0d0a02-eb6 ┆ 21330    ┆ 2fee38b7-f1e ┆ 477         ┆ ... ┆ CC0     ┆ 1200  ┆ 1600   ┆ 0        │
# │ c-4d31-b4f8- ┆          ┆ 1-4f59-a892- ┆             ┆     ┆         ┆       ┆        ┆          │
# │ 96a8123c...  ┆          ┆ 9534f27a...  ┆             ┆     ┆         ┆       ┆        ┆          │
# │ 035eee8e-b16 ┆ 21342    ┆ bc2bf26b-b6c ┆ 477         ┆ ... ┆ CC0     ┆ 1200  ┆ 1600   ┆ 0        │
# │ 0-4e80-af39- ┆          ┆ c-4d8b-93e8- ┆             ┆     ┆         ┆       ┆        ┆          │
# │ 7e307059...  ┆          ┆ 9d223910...  ┆             ┆     ┆         ┆       ┆        ┆          │
# │ 85fa2f9d-eda ┆ 21344    ┆ d2067277-8c4 ┆ 477         ┆ ... ┆ CC0     ┆ 1600  ┆ 1200   ┆ 0        │
# │ a-4bcb-99a5- ┆          ┆ 0-4266-a356- ┆             ┆     ┆         ┆       ┆        ┆          │
# │ 4af044db...  ┆          ┆ a2e907e3...  ┆             ┆     ┆         ┆       ┆        ┆          │
# │ b0cc2cfc-46d ┆ 21351    ┆ 63c6eebc-522 ┆ 477         ┆ ... ┆ CC0     ┆ 1600  ┆ 1200   ┆ 0        │
# │ 2-4b3a-8a32- ┆          ┆ 8-4ed9-8929- ┆             ┆     ┆         ┆       ┆        ┆          │
# │ 90c3dab1...  ┆          ┆ 1d23ef24...  ┆             ┆     ┆         ┆       ┆        ┆          │
# │ ecca6143-2dd ┆ 20187    ┆ 1eb58e5c-3f9 ┆ 477         ┆ ... ┆ CC0     ┆ 2048  ┆ 1365   ┆ 0        │
# │ b-496d-9855- ┆          ┆ 3-4d0a-a258- ┆             ┆     ┆         ┆       ┆        ┆          │
# │ 738fcf48...  ┆          ┆ 14e2579d...  ┆             ┆     ┆         ┆       ┆        ┆          │
# └──────────────┴──────────┴──────────────┴─────────────┴─────┴─────────┴───────┴────────┴──────────┘

# %%
photo_df.shape
# Out:
# (36333510, 9)
