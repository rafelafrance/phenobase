# %%
import sys

sys.path.append("..")

# %%
from pathlib import Path

import pandas as pd

# %%
IMAGE_DIR = Path("../../../images/herbarium_sheets")

# %%
values = []
for image in IMAGE_DIR.glob("*"):
    values.append(image.stat().st_size)

# %%
sizes = pd.Series(values)

# %%
sizes.plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>
